# %%
import pandas as pd

data = pd.read_csv('wine_rev.csv', index_col=0)

data.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
data.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
data.points.astype('float64')

data.points.dtype # It doesn't alter the original dataframe..
# Out:
# dtype('int64')

# %%
data.index.dtype
# Out:
# dtype('int64')

# %%
# Selecting the NaNs in a specific col
data[pd.isnull(data.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# 11150      NaN  A blend of 85% Melnik, 10% Grenache Noir and 5...
# 11348      NaN  Light and fruity, this is a wine that has some...
# 14030      NaN  This Furmint, grown in marl soils, has aromas ...
# 16000      NaN  Jumpy, jammy aromas of foxy black fruits are s...
# 16749      NaN  Winemaker: Bartho Eksteen. This wooded Sauvy s...
# 18075      NaN  Delicate white flowers and a spin of lemon pee...
# 26485      NaN  This wine has aromas of black berry, dried red...
# 26486      NaN  Aromas of green apple and white flowers prepar...
# ...

# %%
len(data[data.country.isnull()])
# Out:
# 63

# %%
data.isnull().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
# data[data.region_1.notnull()]

# %%
# data[pd.notnull(data.region_1)]

# %%
#Replacing missing values...
data.region_2.fillna('unknown').head()
# Out:
# 0              unknown
# 1              unknown
# 2    Willamette Valley
# 3              unknown
# 4    Willamette Valley
# Name: region_2, dtype: object

# %%
data[data.taster_twitter_handle == '@kerinokeefe']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26       Italy  Pretty aromas of yellow flower and stone fruit...
# 27       Italy  Aromas recall ripe dark berry, toast and a whi...
# 28       Italy  Aromas suggest mature berry, scorched earth, a...
# 61       Italy  This densely hued wine has aromas of black plu...
# 72       Italy  Aromas of black-skinned fruit, leather, underb...
# 88       Italy  Subdued aromas of French oak, toast and acacia...
# 89       Italy  Made primarily from Sangiovese, with some Malv...
# 98       Italy  Forest floor, menthol, espresso, cranberry and...
# ...

# %%
data.taster_twitter_handle.replace('@kerinokeefe', '@kerinoo').head(10)
# Out:
# 0       @kerinoo
# 1     @vossroger
# 2    @paulgwine
# 3            NaN
# 4    @paulgwine
# 5    @wineschach
# 6       @kerinoo
# 7     @vossroger
# 8            NaN
# 9     @vossroger
# Name: taster_twitter_handle, dtype: object

# %%
data[data.taster_twitter_handle == '@worldwineguys']
# Out:
#             country                                        description  \
# 202          Israel  This wine features pleasing aromas of raspberr...
# 215          Israel  Aromas of blackberry, fennel bulb and smoke se...
# 219         Hungary  From a vineyard in Northern Tokaj this dry Fur...
# 351         Hungary  This amber-colored Hungarian stunner has ether...
# 873         Hungary  This delicate Hungarian white wine is a blend ...
# 913             NaN  Amber in color, this wine has aromas of peach ...
# 1023         Israel  This offers aromas of honeydew melon and vanil...
# 1187         Turkey  From a winery that specializes in this rare va...
# 1543        Romania  This wine is light straw-colored, with aromas ...
# 2486        Romania  A blend of 50% Sauvignon Blanc, 40% Feteasca A...
# 2501        Romania  This wine made from an indigenous Romanian gra...
# 2747        Romania  Aromas of black plum, black cherry, green bram...
# ...
