# %%
import pandas as pd

data = pd.read_csv('countries.csv')

data.head()
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
# The 1st row

data.iloc[0]
# Out:
# country       Afghanistan
# year                 1952
# population        8425333
# Name: 0, dtype: object

# %%
# First two rows
data.iloc[:2]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934

# %%
# First three items in the year col
data.iloc[:3, 1]
# Out:
# 0    1952
# 1    1957
# 2    1962
# Name: year, dtype: int64

# %%
# First ten rows for the 1st two cols
data.iloc[:10, :2]
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967
# 4  Afghanistan  1972
# 5  Afghanistan  1977
# 6  Afghanistan  1982
# 7  Afghanistan  1987
# 8  Afghanistan  1992
# 9  Afghanistan  1997

# %%
data.iloc[20]
# Out:
# country       Albania
# year             1992
# population    3326498
# Name: 20, dtype: object

# %%
# Selecting a scalar value

data.iloc[4, 1]
# Out:
# 1972

# %%
data.iloc[[12, 45, 67, 76], [0, 2]]
# Out:
#       country  population
# 12    Albania     1282697
# 45     Angola     9875024
# 67  Australia    16257249
# 76    Austria     7544201

# %%
data.iloc[:8, 0]
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# 5    Afghanistan
# 6    Afghanistan
# 7    Afghanistan
# Name: country, dtype: object

# %%
# Using the index value and not the position
# loc

data.loc[15:20, 'country']
# Out:
# 15    Albania
# 16    Albania
# 17    Albania
# 18    Albania
# 19    Albania
# 20    Albania
# Name: country, dtype: object

# %%
data.loc[:3, ['country', 'year']]
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967

# %%
data.iloc[:3, :2]
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962

# %%
data.loc[data['country'] == 'Kenya']
# Out:
#     country  year  population
# 816   Kenya  1952     6464046
# 817   Kenya  1957     7454779
# 818   Kenya  1962     8678557
# 819   Kenya  1967    10191512
# 820   Kenya  1972    12044785
# 821   Kenya  1977    14500404
# 822   Kenya  1982    17661452
# 823   Kenya  1987    21198082
# 824   Kenya  1992    25020539
# 825   Kenya  1997    28263827
# 826   Kenya  2002    31386842
# 827   Kenya  2007    35610177

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
kenya = data[data.country == 'Kenya']

kenya
# Out:
#     country  year  population
# 816   Kenya  1952     6464046
# 817   Kenya  1957     7454779
# 818   Kenya  1962     8678557
# 819   Kenya  1967    10191512
# 820   Kenya  1972    12044785
# 821   Kenya  1977    14500404
# 822   Kenya  1982    17661452
# 823   Kenya  1987    21198082
# 824   Kenya  1992    25020539
# 825   Kenya  1997    28263827
# 826   Kenya  2002    31386842
# 827   Kenya  2007    35610177

# %%
uganda = data[data.country == 'Uganda']

# %%
sns.lineplot(x=kenya.year, y=kenya.population / 10**6, label='Kenya')
sns.lineplot(x=uganda.year, y=uganda.population / 10**6, label='Uganda')

# %%
data.loc[data.country == 'Kenya']
# Out:
#     country  year  population
# 816   Kenya  1952     6464046
# 817   Kenya  1957     7454779
# 818   Kenya  1962     8678557
# 819   Kenya  1967    10191512
# 820   Kenya  1972    12044785
# 821   Kenya  1977    14500404
# 822   Kenya  1982    17661452
# 823   Kenya  1987    21198082
# 824   Kenya  1992    25020539
# 825   Kenya  1997    28263827
# 826   Kenya  2002    31386842
# 827   Kenya  2007    35610177

# %%
them = data[(data.country == 'Kenya') & (data.year >= 1982)]
them
# Out:
#     country  year  population
# 822   Kenya  1982    17661452
# 823   Kenya  1987    21198082
# 824   Kenya  1992    25020539
# 825   Kenya  1997    28263827
# 826   Kenya  2002    31386842
# 827   Kenya  2007    35610177

# %%
two = data[(data.country == 'Kenya') | (data.country == 'Uganda')]
# two

# %%
four = data[(data.country.isin(['Kenya', 'Uganda'])) & (data.year.isin([1962, 1982, 2007]))]
four
# Out:
#      country  year  population
# 818    Kenya  1962     8678557
# 822    Kenya  1982    17661452
# 827    Kenya  2007    35610177
# 1586  Uganda  1962     7688797
# 1590  Uganda  1982    12939400
# 1595  Uganda  2007    29170398

# %%
three = data[data.country.isin(['Brazil', 'Nigeria', 'Spain'])]
# three

# %%
# More data to show isnull() and notnull

melb = pd.read_csv('melb_data.csv')

# The col where the values are null

melb.loc[melb.Car.isnull()]
# Out:
#                 Suburb            Address  Rooms Type    Price Method  \
# 12221       Ascot Vale     132 The Parade      3    h   985000      S
# 12247   Brunswick East        18 Ethel St      2    h  1023000      S
# 12259     Clifton Hill      34 Fenwick St      3    h  1436000      S
# 12320    Glen Waverley      19 Diamond Av      3    h  1370000      S
# 12362          Newport  11 Collingwood Rd      4    h  1180000     PI
# 12383   Port Melbourne     333 Princes St      3    h  1764000      S
# 12397  South Melbourne        303 Park St      2    h  1137000      S
# 12426       Yarraville       54 Sussex St      3    h   890000     VB
# 12462          Carlton      81 Princes St      2    h   800000     VB
# 12463    Carlton North       782 Lygon St      2    h  1065000      S
# 12464    Carlton North       125 Newry St      2    h   950000     VB
# 12474         Cremorne       22 Cubitt St      2    h  1200000     SP
# ...

# %%
melb.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
melb.shape
# Out:
# (13580, 21)

# %%
# Where the building area is not null

melb.loc[melb.BuildingArea.notnull()]
# Out:
#                   Suburb              Address  Rooms Type    Price Method  \
# 1             Abbotsford      25 Bloomburg St      2    h  1035000      S
# 2             Abbotsford         5 Charles St      3    h  1465000     SP
# 4             Abbotsford          55a Park St      4    h  1600000     VB
# 6             Abbotsford         124 Yarra St      3    h  1876000      S
# 7             Abbotsford        98 Charles St      2    h  1636000      S
# 9             Abbotsford        10 Valiant St      2    h  1097000      S
# 11            Abbotsford      40 Nicholson St      3    h  1350000     VB
# 12            Abbotsford  123/56 Nicholson St      2    u   750000      S
# 15            Abbotsford        16 William St      2    h  1310000      S
# 16            Abbotsford          42 Henry St      3    h  1200000      S
# 17            Abbotsford          78 Yarra St      3    h  1176500      S
# 19            Abbotsford        42 Valiant St      2    h   890000      S
# ...

# %%
# Assigning Values to a DataFrame

# %%
# Let's play around with the countries.csv

# Adding a Constant Value
data['fucked'] = 'YEEEESSSs'

data.head()
# Out:
#        country  year  population     fucked
# 0  Afghanistan  1952     8425333  YEEEESSSs
# 1  Afghanistan  1957     9240934  YEEEESSSs
# 2  Afghanistan  1962    10267083  YEEEESSSs
# 3  Afghanistan  1967    11537966  YEEEESSSs
# 4  Afghanistan  1972    13079460  YEEEESSSs

# %%
# Adding an Iterable of Values
data['index_backwards'] = range(len(data), 0, -1)

data.head(15)
# Out:
#         country  year  population     fucked  index_backwards
# 0   Afghanistan  1952     8425333  YEEEESSSs             1704
# 1   Afghanistan  1957     9240934  YEEEESSSs             1703
# 2   Afghanistan  1962    10267083  YEEEESSSs             1702
# 3   Afghanistan  1967    11537966  YEEEESSSs             1701
# 4   Afghanistan  1972    13079460  YEEEESSSs             1700
# 5   Afghanistan  1977    14880372  YEEEESSSs             1699
# 6   Afghanistan  1982    12881816  YEEEESSSs             1698
# 7   Afghanistan  1987    13867957  YEEEESSSs             1697
# 8   Afghanistan  1992    16317921  YEEEESSSs             1696
# 9   Afghanistan  1997    22227415  YEEEESSSs             1695
# 10  Afghanistan  2002    25268405  YEEEESSSs             1694
# 11  Afghanistan  2007    31889923  YEEEESSSs             1693
# 12      Albania  1952     1282697  YEEEESSSs             1692
# 13      Albania  1957     1476505  YEEEESSSs             1691
# ...

# %%
data.tail(10)
# Out:
#        country  year  population     fucked  index_backwards
# 1694  Zimbabwe  1962     4277736  YEEEESSSs               10
# 1695  Zimbabwe  1967     4995432  YEEEESSSs                9
# 1696  Zimbabwe  1972     5861135  YEEEESSSs                8
# 1697  Zimbabwe  1977     6642107  YEEEESSSs                7
# 1698  Zimbabwe  1982     7636524  YEEEESSSs                6
# 1699  Zimbabwe  1987     9216418  YEEEESSSs                5
# 1700  Zimbabwe  1992    10704340  YEEEESSSs                4
# 1701  Zimbabwe  1997    11404948  YEEEESSSs                3
# 1702  Zimbabwe  2002    11926563  YEEEESSSs                2
# 1703  Zimbabwe  2007    12311143  YEEEESSSs                1

# %%
# SUmmary FUnctions and Maps

data.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
data.describe()
# Out:
#              year    population  index_backwards
# count  1704.00000  1.704000e+03      1704.000000
# mean   1979.50000  2.960121e+07       852.500000
# std      17.26533  1.061579e+08       492.046746
# min    1952.00000  6.001100e+04         1.000000
# 25%    1965.75000  2.793664e+06       426.750000
# 50%    1979.50000  7.023596e+06       852.500000
# 75%    1993.25000  1.958522e+07      1278.250000
# max    2007.00000  1.318683e+09      1704.000000

# %%
len(data.country.unique())
# Out:
# 142

# %%
data.country.nunique()
# Out:
# 142

# %%
# Unique Values and how often they occur
data.country.value_counts()
# Out:
# Hungary             12
# Ireland             12
# Korea, Dem. Rep.    12
# Guinea-Bissau       12
# Mongolia            12
# Pakistan            12
# Montenegro          12
# Ghana               12
# Venezuela           12
# Zambia              12
# Iceland             12
# Uganda              12
# Czech Republic      12
# Egypt               12
# Romania             12
# Iraq                12
# Afghanistan         12
# Cuba                12
# Sri Lanka           12
# Costa Rica          12
# Israel              12
# Indonesia           12
# Burundi             12
# Malawi              12
# Guatemala           12
# Taiwan              12
# Turkey              12
# Algeria             12
# Panama              12
# New Zealand         12
#                     ..
# Iran                12
# Tanzania            12
# Gambia              12
# Ethiopia            12
# United States       12
# China               12
# Jamaica             12
# Cameroon            12
# Congo, Rep.         12
# ...
