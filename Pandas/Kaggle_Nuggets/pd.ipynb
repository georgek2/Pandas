# %%
import pandas as pd

# %%
data = pd.read_csv('wine_rev.csv', index_col=0)
data.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
sub_set = data[['country', 'points', 'price', 'winery']]

sub_set.head()
# Out:
#     country  points  price               winery
# 0     Italy      87    NaN              Nicosia
# 1  Portugal      87   15.0  Quinta dos Avidagos
# 2        US      87   14.0            Rainstorm
# 3        US      87   13.0           St. Julian
# 4        US      87   65.0         Sweet Cheeks

# %%
two = data.loc[:, ['country','province', 'points', 'price', 'winery']]

two.head(10)
# Out:
#     country           province  points  price               winery
# 0     Italy  Sicily & Sardinia      87    NaN              Nicosia
# 1  Portugal              Douro      87   15.0  Quinta dos Avidagos
# 2        US             Oregon      87   14.0            Rainstorm
# 3        US           Michigan      87   13.0           St. Julian
# 4        US             Oregon      87   65.0         Sweet Cheeks
# 5     Spain     Northern Spain      87   15.0               Tandem
# 6     Italy  Sicily & Sardinia      87   16.0      Terre di Giurfo
# 7    France             Alsace      87   24.0             Trimbach
# 8   Germany        Rheinhessen      87   12.0          Heinz Eifel
# 9    France             Alsace      87   27.0   Jean-Baptiste Adam

# %%
two[two.points >= 95]
# Out:
#           country  points   price                              winery
# 345     Australia     100   350.0         Chambers Rosewood Vineyards
# 346     Australia      98   350.0         Chambers Rosewood Vineyards
# 347       Germany      97   775.0                         Robert Weil
# 348     Australia      97   100.0         Chambers Rosewood Vineyards
# 349     Australia      97   225.0                            Torbreck
# 350         Italy      97   150.0                          Cavallotto
# 351       Hungary      96   320.0                              Oremus
# 352            US      96    68.0                            Rochioli
# 353        France      96   630.0                        Louis Latour
# 354       Germany      96   365.0                         Robert Weil
# 355            US      96    68.0                            Rochioli
# 356     Australia      95    85.0                         Jasper Hill
# ...

# %%
two.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                                  country             province  points  price  \
# country   province
# Argentina Mendoza Province     Argentina     Mendoza Province      97  120.0
#           Other                Argentina                Other      95   90.0
# Armenia   Armenia                Armenia              Armenia      88   15.0
# Australia Australia Other      Australia      Australia Other      93   15.0
#           New South Wales      Australia      New South Wales      94   32.0
#           South Australia      Australia      South Australia      99  850.0
#           Tasmania             Australia             Tasmania      94   60.0
#           Victoria             Australia             Victoria     100  350.0
#           Western Australia    Australia    Western Australia      95   84.0
# Austria   Austria                Austria              Austria      93    NaN
#           Burgenland             Austria           Burgenland      98    NaN
# ...
